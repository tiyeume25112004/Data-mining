# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
os.listdir("./")
# Out:
# ['.ipynb_checkpoints', 'Groceries_dataset.csv', 'Untitled.ipynb']

# %%
df = pd.read_csv("./Groceries_dataset.csv")

# %% [markdown]
# # KIỂM TRA THÔNG TIN

# %% [markdown]
# - kiểm tra số các thuộc tính và quan sát

# %%
df.info
# có 38765 quan sát và 3 thuộc tính: member_number, Date, itemDescription
# Out:
# <bound method DataFrame.info of        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]>

# %% [markdown]
# - xem 5 dòng đầu tiên

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %% [markdown]
# - kiểm tra xem có thuộc tính nào null không

# %%
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %% [markdown]
# - lọc các thông về người dùng có id là 2300 và sort theo Date

# %%
user_2300_info = df[df['Member_number']==2051]
user_2300_info.sort_values(by='Date')
# Out:
#        Member_number        Date           itemDescription
# 37603           2051  01-05-2014             cream cheese
# 33052           2051  01-05-2014                     flour
# 3441            2051  02-01-2015                photo/film
# 34748           2051  02-01-2015              cocoa drinks
# 19590           2051  02-01-2015             domestic eggs
# 32805           2051  03-12-2014                newspapers
# 29434           2051  03-12-2014          other vegetables
# 13285           2051  03-12-2014                rolls/buns
# 32203           2051  11-09-2015        whipped/sour cream
# 21164           2051  11-09-2015                 pip fruit
# 36199           2051  11-09-2015          hygiene articles
# 16054           2051  11-09-2015  long life bakery product
# 20153           2051  11-09-2015                newspapers
# 4004            2051  11-09-2015               frankfurter
# 5015            2051  11-09-2015               frankfurter
# ...

# %% [markdown]
# - lấy thông tin người dùng id là 1234 và 4321

# %%
df[(df['Member_number']==1234) | (df['Member_number']==4321)].sort_values(by=["Date",'Member_number'])
# Out:
#        Member_number        Date  itemDescription
# 2888            4321  08-05-2015             curd
# 7285            4321  08-05-2015      frankfurter
# 19037           4321  08-05-2015      white bread
# 23434           4321  08-05-2015        pip fruit
# 34949           4321  08-05-2015          waffles
# 14039           1234  12-05-2014             curd
# 30188           1234  12-05-2014           pastry
# 6174            4321  12-09-2015          sausage
# 22323           4321  12-09-2015       newspapers
# 14174           4321  13-08-2014           grapes
# 30323           4321  13-08-2014  misc. beverages
# 13617           4321  14-01-2014           yogurt
# 29766           4321  14-01-2014             soda
# 10930           1234  14-04-2014           yogurt
# 27079           1234  14-04-2014    shopping bags
# 34337           1234  14-04-2014           coffee
# 12363           1234  16-03-2014  root vegetables
# 28512           1234  16-03-2014        margarine
# ...

# %% [markdown]
# - kiểm tra các mặt hàng không trùng lặp

# %%
print(df.itemDescription.unique())
len(df.itemDescription.unique())
# Out:
# ['tropical fruit' 'whole milk' 'pip fruit' 'other vegetables' 'rolls/buns'
#  'pot plants' 'citrus fruit' 'beef' 'frankfurter' 'chicken' 'butter'
#  'fruit/vegetable juice' 'packaged fruit/vegetables' 'chocolate'
#  'specialty bar' 'butter milk' 'bottled water' 'yogurt' 'sausage'
#  'brown bread' 'hamburger meat' 'root vegetables' 'pork' 'pastry'
#  'canned beer' 'berries' 'coffee' 'misc. beverages' 'ham' 'turkey'
#  'curd cheese' 'red/blush wine' 'frozen potato products' 'flour' 'sugar'
#  'frozen meals' 'herbs' 'soda' 'detergent' 'grapes' 'processed cheese'
#  'fish' 'sparkling wine' 'newspapers' 'curd' 'pasta' 'popcorn'
#  'finished products' 'beverages' 'bottled beer' 'dessert' 'dog food'
#  'specialty chocolate' 'condensed milk' 'cleaner' 'white wine' 'meat'
#  'ice cream' 'hard cheese' 'cream cheese ' 'liquor' 'pickled vegetables'
#  'liquor (appetizer)' 'UHT-milk' 'candy' 'onions' 'hair spray'
#  'photo/film' 'domestic eggs' 'margarine' 'shopping bags' 'salt' 'oil'
# ...

# %% [markdown]
# # Tiền xử lý dữ liệu

# %% [markdown]
# - kiểm tra các thành phần trùng lặp

# %%
# Có 759 giá trị trùng lặp
df[df.duplicated]
# Out:
#        Member_number        Date   itemDescription
# 5015            2051  11-09-2015       frankfurter
# 5022            3055  18-08-2015  other vegetables
# 5044            1994  11-03-2015        whole milk
# 5055            1682  25-06-2015         pip fruit
# 5059            4324  05-01-2015           sausage
# ...              ...         ...               ...
# 38614           2027  26-02-2014     domestic eggs
# 38684           2936  07-03-2014        newspapers
# 38685           2311  13-03-2014        pot plants
# 38722           3834  18-05-2014       salty snack
# 38723           1146  23-05-2014            yogurt
#
# [759 rows x 3 columns]

# %% [markdown]
# - Kiểm tra người dùng có thực sự trùng lặp không bằng cách check lại

# %%
"""Kết quả là có trùng lặp như đã nhận định"""
df[(df['Member_number']==2051) & (df['itemDescription']=='frankfurter')].sort_values(by='itemDescription')
# Out:
#       Member_number        Date itemDescription
# 4004           2051  11-09-2015     frankfurter
# 5015           2051  11-09-2015     frankfurter

# %%
# loại bỏ trùng lặp, giữ lại lần xuất hiện đầu tiên
df = df.drop_duplicates(keep='first')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38006 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38006 non-null  int64
#  1   Date             38006 non-null  object
#  2   itemDescription  38006 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
# tách date -> thành day/month/year/
from datetime import datetime

df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Sau đó tạo các cột ngày, tháng, năm
df.loc[:, 'day'] = df['Date'].dt.day
df.loc[:, 'month'] = df['Date'].dt.month
df.loc[:, 'year'] = df['Date'].dt.year
month_change = {"1":"Jan","2":"Feb","3":"Mar","4":"Apr","5":"May","6":"Jun","7":"Jul","8":"Aug","9":"Sep",
               "10":"Oct","11":"Nov","12":"Dec"}
df['month'] = df['month'].astype(str).apply(lambda x: month_change.get(x, x)) 
df['DayOfWeek'] = df['Date'].dt.day_name()
# Out:
# C:\Users\Zlick3r\AppData\Local\Temp\ipykernel_27416\3206688002.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
# C:\Users\Zlick3r\AppData\Local\Temp\ipykernel_27416\3206688002.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'day'] = df['Date'].dt.day
# C:\Users\Zlick3r\AppData\Local\Temp\ipykernel_27416\3206688002.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#        Member_number       Date        itemDescription  day month  year  \
# 0               1808 2015-07-21         tropical fruit   21   Jul  2015
# 1               2552 2015-01-05             whole milk    5   Jan  2015
# 2               2300 2015-09-19              pip fruit   19   Sep  2015
# 3               1187 2015-12-12       other vegetables   12   Dec  2015
# 4               3037 2015-02-01             whole milk    1   Feb  2015
# ...              ...        ...                    ...  ...   ...   ...
# 38760           4471 2014-10-08          sliced cheese    8   Oct  2014
# 38761           2022 2014-02-23                  candy   23   Feb  2014
# 38762           1097 2014-04-16               cake bar   16   Apr  2014
# 38763           1510 2014-12-03  fruit/vegetable juice    3   Dec  2014
# 38764           1521 2014-12-26               cat food   26   Dec  2014
#
#        DayOfWeek
# 0        Tuesday
# 1         Monday
# 2       Saturday
# 3       Saturday
# ...

# %% [markdown]
# - chuyển tháng từ số thành chữ tiếng anh

# %% [markdown]
# - tìm ngày trong tuần ứng với dữ liệu đã cho

# %%
from datetime import datetime
df['DayOfWeek'] = df['Date'].dt.day_name()
df
# Out:
# C:\Users\Zlick3r\AppData\Local\Temp\ipykernel_27416\4085055800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df['Date'].dt.day_name()
#        Member_number       Date        itemDescription  day month  year  \
# 0               1808 2015-07-21         tropical fruit   21   Jul  2015
# 1               2552 2015-01-05             whole milk    5   Jan  2015
# 2               2300 2015-09-19              pip fruit   19   Sep  2015
# 3               1187 2015-12-12       other vegetables   12   Dec  2015
# 4               3037 2015-02-01             whole milk    1   Feb  2015
# ...              ...        ...                    ...  ...   ...   ...
# ...

# %% [markdown]
# - lấy các dữ liệu thứ 2

# %%
Monday_ = df[df['DayOfWeek']=="Friday"]
Monday_
# Out:
#        Member_number       Date   itemDescription  day month  year DayOfWeek
# 6               4501 2015-05-08  other vegetables    8   May  2015    Friday
# 8               2762 2015-03-20        whole milk   20   Mar  2015    Friday
# 22              3962 2015-09-18    tropical fruit   18   Sep  2015    Friday
# 24              4976 2015-07-17     bottled water   17   Jul  2015    Friday
# 25              4056 2015-06-12            yogurt   12   Jun  2015    Friday
# ...              ...        ...               ...  ...   ...   ...       ...
# 38749           4153 2014-02-14         chocolate   14   Feb  2014    Friday
# 38751           4444 2014-04-25            pastry   25   Apr  2014    Friday
# 38752           2824 2014-09-05   cling film/bags    5   Sep  2014    Friday
# 38755           4586 2014-09-26     bottled water   26   Sep  2014    Friday
# 38764           1521 2014-12-26          cat food   26   Dec  2014    Friday
#
# [5451 rows x 7 columns]

# %%
DayOfWeek = df.groupby('DayOfWeek').size().reindex(
    ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
)
print(DayOfWeek)
# kiểm tra số lượng mặt hàng mua trong các thứ này


day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# Sắp xếp cột dayOfWeek theo thứ tự các ngày trong tuần
# Out:
# DayOfWeek
# Monday       5278
# Tuesday      5433
# Wednesday    5470
# Thursday     5510
# Friday       5451
# Saturday     5444
# Sunday       5420
# dtype: int64

# %%
#df['DayOfWeek'] = pd.Categorical(df['DayOfWeek'], categories=day_order, ordered=True)
#df

# %%
# Vẽ biểu đồ để đánh giá mức mua tập trung nhiều vào ngày nào

plt.figure(figsize=(14,7))
DayOfWeek.plot(kind='line')
plt.title('DayOfWeek Purchases')
plt.ylabel('Number of Transactions')
plt.xlabel('DayOfWeek')
plt.grid(True)
plt.show()

# %%
item_monthly_sales = df.groupby(['DayOfWeek', 'itemDescription']).size().unstack().fillna(0)
item_monthly_sales.sort_values(by='vinegar')
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# DayOfWeek
# Thursday                           6.0      40.0               2.0
# Friday                             7.0      40.0               2.0
# Monday                             5.0      48.0               2.0
# Wednesday                         15.0      51.0               7.0
# Tuesday                            6.0      38.0               3.0
# Saturday                           8.0      44.0               3.0
# Sunday                            13.0      59.0               3.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# DayOfWeek
# Thursday                      2.0             1.0   1.0           16.0
# Friday                        5.0             1.0   0.0           17.0
# Monday                        6.0             0.0   1.0           20.0
# Wednesday                     5.0             0.0   1.0           14.0
# ...

# %%
top_items = df['itemDescription'].value_counts().nlargest(15)
print("Top 10 mặt hàng được mua nhiều nhất:")
print(top_items)
# Out:
# Top 10 mặt hàng được mua nhiều nhất:
# itemDescription
# whole milk          2363
# other vegetables    1827
# rolls/buns          1646
# soda                1453
# yogurt              1285
# root vegetables     1041
# tropical fruit      1014
# bottled water        908
# sausage              903
# citrus fruit         795
# pastry               774
# pip fruit            734
# shopping bags        712
# canned beer          702
# bottled beer         678
# Name: count, dtype: int64

# %%
top_items_over_time = df[df['itemDescription'].isin(top_items.index)]

# Get the colors from the tab20 colormap
colors = plt.cm.tab20.colors

# Plotting
plt.figure(figsize=(25,15))
for idx, item in enumerate(top_items.index):
    monthly_data = top_items_over_time[top_items_over_time['itemDescription'] == item].groupby('DayOfWeek').size()
    monthly_data.plot(label=item, color=colors[idx])

plt.legend()
plt.title('Top 15 Items Purchased Over Time')
plt.ylabel('Number of Transactions')
plt.xlabel('Month')
plt.grid(True)
plt.show()

# %%
df
# Out:
#        Member_number       Date        itemDescription  day month  year  \
# 0               1808 2015-07-21         tropical fruit   21   Jul  2015
# 1               2552 2015-01-05             whole milk    5   Jan  2015
# 2               2300 2015-09-19              pip fruit   19   Sep  2015
# 3               1187 2015-12-12       other vegetables   12   Dec  2015
# 4               3037 2015-02-01             whole milk    1   Feb  2015
# ...              ...        ...                    ...  ...   ...   ...
# 38760           4471 2014-10-08          sliced cheese    8   Oct  2014
# 38761           2022 2014-02-23                  candy   23   Feb  2014
# 38762           1097 2014-04-16               cake bar   16   Apr  2014
# 38763           1510 2014-12-03  fruit/vegetable juice    3   Dec  2014
# 38764           1521 2014-12-26               cat food   26   Dec  2014
#
#        DayOfWeek
# 0        Tuesday
# 1         Monday
# 2       Saturday
# 3       Saturday
# ...

# %%
combinacoes = df.groupby(['Member_number','DayOfWeek']).agg({"itemDescription":list}).reset_index()

# %%
combinacoes
# Out:
#        Member_number  DayOfWeek  \
# 0               1000     Friday
# 1               1000     Sunday
# 2               1000    Tuesday
# 3               1000  Wednesday
# 4               1001     Friday
# ...              ...        ...
# 11555           4999     Monday
# 11556           4999   Saturday
# 11557           4999  Wednesday
# 11558           5000     Sunday
# 11559           5000    Tuesday
#
#                                          itemDescription
# 0                         [canned beer, misc. beverages]
# 1      [sausage, whole milk, semi-finished bread, yog...
# 2                      [whole milk, pastry, salty snack]
# 3      [soda, sausage, pickled vegetables, hygiene ar...
# 4      [sausage, whole milk, whole milk, soda, rolls/...
# ...                                                  ...
# 11555                      [other vegetables, detergent]
# 11556  [bottled water, butter milk, tropical fruit, b...
# ...

# %%
combinacoes_list = combinacoes['itemDescription'].tolist()
combinacoes_list
# Out:
# [['canned beer', 'misc. beverages'],
#  ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'],
#  ['whole milk', 'pastry', 'salty snack'],
#  ['soda', 'sausage', 'pickled vegetables', 'hygiene articles'],
#  ['sausage', 'whole milk', 'whole milk', 'soda', 'rolls/buns'],
#  ['frankfurter', 'curd'],
#  ['frankfurter', 'beef', 'soda', 'white bread', 'whipped/sour cream'],
#  ['butter', 'whole milk'],
#  ['tropical fruit',
#   'butter milk',
#   'frozen vegetables',
#   'sugar',
#   'specialty chocolate',
#   'other vegetables'],
#  ['frozen meals', 'dental care'],
#  ['rolls/buns'],
#  ['sausage', 'rolls/buns'],
#  ['root vegetables', 'detergent'],
#  ['whole milk', 'chocolate', 'packaged fruit/vegetables', 'rolls/buns'],
#  ['other vegetables', 'shopping bags', 'dish cleaner', 'cling film/bags'],
#  ['pip fruit',
#   'root vegetables',
#   'canned beer',
#   'rolls/buns',
#   'whole milk',
#   'whole milk',
#   'frozen fish',
#   'red/blush wine',
#   'tropical fruit',
# ...

# %%
from apyori import apriori

# %%
#rules = apriori(combinacoes_list, min_support=0.01, min_confidence=0.4, min_lift=1, min_length=2, max_length=2)
rules = apriori(combinacoes_list, min_support=0.01, min_confidence=0.2, min_length=2, max_length=2)

# %%
results = list(rules)
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    support = [result[1]*100 for result in results]
    confidence = [result[2][0][2]*100 for result in results]
    # lift = [result[2][0][3] for result in results]
    #return list(zip(lhs,rhs,support,confidence,lift))
#final_result = pd.DataFrame(inspect(results), columns=['Product 1','Product 2','Support(%)','Confidence(%)','lift'])
    return list(zip(lhs,rhs,support,confidence))
final_result = pd.DataFrame(inspect(results), columns=['Product 1','Product 2','Support(%)','Confidence(%)'])

#test_ = list(final_result['Product 1'],final_result['Product 2'])
final_result['Rule'] = final_result['Product 1'] + '->' + final_result['Product 2']

# %%
final_result
# Out:
#       Product 1   Product 2  Support(%)  Confidence(%)  \
# 0  bottled beer  whole milk    1.366782      23.582090
# 1   canned beer  whole milk    1.228374      20.461095
# 2    newspapers  whole milk    1.003460      20.138889
# 3        pastry  whole milk    1.375433      20.893561
# 4     pip fruit  whole milk    1.314879      21.052632
# 5       sausage  whole milk    1.669550      21.661055
# 6        yogurt  whole milk    2.214533      20.349762
#
#                        Rule
# 0  bottled beer->whole milk
# 1   canned beer->whole milk
# 2    newspapers->whole milk
# 3        pastry->whole milk
# 4     pip fruit->whole milk
# 5       sausage->whole milk
# 6        yogurt->whole milk

# %% [markdown]
# # Trực quan dữ liệu

# %%
import seaborn as sns #final_result

heatmap_data = final_result[['Rule', 'lift']].set_index('Rule')

# Vẽ Heatmap cho Lift
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data.T, annot=True, cmap='YlGnBu', fmt='.2f', linewidths=0.5)

# Thêm tiêu đề
plt.title('Heatmap of Lift for Association Rules', fontsize=16)

# Hiển thị
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 import seaborn as sns #final_result
# ----> 3 heatmap_data = final_result[['Rule', 'lift']].set_index('Rule')
#       5 # Vẽ Heatmap cho Lift
#       6 plt.figure(figsize=(10, 6))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
